# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D

# %%
import numpy as np
np.random.seed(42)

xs1 = 2 * np.random.rand(100, 1)
xs2 = 2 * np.random.rand(100, 1)
ys = 4 + 3 * xs1 + np.random.rand(100, 1) + 3 * xs2 + np.random.rand(100, 1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs1, ys, xs2, c="blue")
plt.show()

# %%
# split the data into training and test sets
# train set
train_xs1 = xs1[:80]
train_xs2 = xs2[:80]
train_ys = ys[:80]
# test set
test_xs1 = xs1[80:]
test_xs2 = xs2[80:]
test_ys = ys[80:]

# %% [markdown]
# # Linear regression using numpy

# %%
# number of epochs
epochs = 10
# learning rate
lr = 0.01

# %%
# initial value for weights w1 and w2 and bias b
w1 = np.random.randn(1)
w2 = np.random.randn(1)
b = np.zeros(1)

# %%
for epoch in np.arange(epochs):
  for i in np.arange(80):
    y_pred = w1 * train_xs1[i] + w2 * train_xs2[i] + b
    
    grad_w1 = (y_pred - train_ys[i]) * train_xs1[i]
    grad_w2 = (y_pred - train_ys[i]) * train_xs2[i]
    grad_b = (y_pred - train_ys[i])
    
    w1 -= lr * grad_w1
    w2 -= lr * grad_w2
    b -= lr * grad_b

# %%
test_loss = 0
for i in np.arange(20):
  test_loss += 0.5 * (w1 * test_xs1[i] + w2 * test_xs2[i] + b - test_ys[i]) ** 2
test_loss /= 20

# %%
test_loss
# Out:
# array([0.09614979])

# %%
pred_ys = w1 * test_xs1 + w2 * test_xs2 + b

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(test_xs1, test_ys, test_xs2, c="blue")
ax.scatter(test_xs1, pred_ys, test_xs2, c="red")  #predicted
plt.show()

# %%
b
# Out:
# array([4.36886087])

# %%
w1
# Out:
# array([3.28930784])

# %%
w2
# Out:
# array([3.32385511])
